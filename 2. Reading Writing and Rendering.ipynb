# %% [markdown]
# # 1. Importing Dependencies

# %%
import cv2
import os

# %% [markdown]
# # 2. Read in Image

# %%
img_path=os.path.join('data','images','bike.jpg')
# img_path=os.path.join('data','images','flare.jpeg')

# %%
img_path
# Out:
# 'data\\images\\bike.jpg'

# %%
img=cv2.imread(img_path)

# %%
img.shape
# Out:
# (704, 564, 3)

# %%
height,width,channels = img.shape
# (hight,width,number of chanels)
# As it is a color image we get Blue layer -> Green Layer -> Red layer

# %%
channels
# Out:
# 3

# %% [markdown]
# # 3. Render Image

# %%
# !pip install matplotlib

# %%
from matplotlib import pyplot as plt
# Show image
plt.imshow(img);

# %%
recolor=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(recolor)
plt.show()

# %% [markdown]
# # 4. Write out Image

# %%
cv2.imwrite('grayimage.jpg',gray)
# Out:
# True

# %%
# !cd data & mkdir output
output_path=os.path.join('data','output','grayimage.jpg')
cv2.imwrite(output_path,gray)
# Out:
# True
